# %% [markdown]
# <a href="https://colab.research.google.com/github/ellieleut/introToML/blob/main/pythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python as a calculator
# Define variables
Conversion_factor = 5/9
TempTodayinF = 47
FreezingPointF = 32
TempTodayinC = Conversion_factor*(TempTodayinF - FreezingPointF)
TempTodayinC
# Out:
# 8.333333333333334

# %%
a = 2
type(a)
# Out:
# int

# %%
b = 4e-7
type(b)
# Out:
# float
