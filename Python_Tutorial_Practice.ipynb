# %% [markdown]
# <a href="https://colab.research.google.com/github/ellieleut/introToML/blob/main/Python_Tutorial_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the sys module
import sys
# Print the Python version
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
print("Hello, Google Colab!")
# Out:
# Hello, Google Colab!

# %%
print("This is the Pre-Class Task submission for Ellie Leutenegger")
# Out:
# This is the Pre-Class Task submission for Ellie Leutenegger
